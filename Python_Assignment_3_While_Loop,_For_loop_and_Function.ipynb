# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishakhmohan77/Python-Assignments./blob/main/Python_Assignment_3_While_Loop%2C_For_loop_and_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#While Loop, For loop and Function (else, break, continue, pass)
# Generate random number between 1 and 10
# 1)
import random
secret_number = random.randint(1, 10)
print(secret_number)
# Out:
# 3

# %%
# 2: Prompt the User & Set Attempts
import random
secret_number = random.randint(1, 10)
attempts = 3

# %%
import random
secret_number = random.randint(1, 10)
attempts = 3

while attempts > 0:
  guess = int(input("Guess the number (between 1 and 10): "))

  if guess < 1 or guess > 10:
    print("Your guess is out of range. Please guess a number between 1 and 10.")
    continue
  elif guess > secret_number:
    print("Too high. Try again.")
    attempts -= 1
  elif guess < secret_number:
    print("Too low. Try again.")
    attempts -= 1
  else:
    print("Congratulations! You guessed the correct number.")
    break
# Out:
# Guess the number (between 1 and 10): 5
# Too high. Try again.
# Guess the number (between 1 and 10): 8
# Too high. Try again.
# Guess the number (between 1 and 10): 2
# Too high. Try again.

# %%
#Control Statements:

import random

secret_number = random.randint(1, 10)
attempts = 3

while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10): "))

    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue

    elif guess > secret_number:
        print("Too high. Try again.")
        attempts -= 1

    elif guess < secret_number:
        print("Too low. Try again.")
        attempts -= 1

    else:
        print("Congratulations! You guessed the correct number.")
        break

else:
    print("Better luck next time!")
# Out:
# Guess the number (between 1 and 10): 4
# Too low. Try again.
# Guess the number (between 1 and 10): 15
# Your guess is out of range. Please guess a number between 1 and 10.
# Guess the number (between 1 and 10): 3
# Too low. Try again.
# Guess the number (between 1 and 10): 7
# Too low. Try again.
# Better luck next time!

# %%
# For Loop:  Multiplication Table Generator

number = int(input("Enter the number for which you want the multiplication table: "))

for i in range(1, 11):
    result = number * i
    print(number, "x", i, "=", result)
# Out:
# Enter the number for which you want the multiplication table: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
# Function:

def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))
bmi = calculate_bmi(weight, height)
print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 86
# Enter your height in meters: 1.87
# Your BMI is: 24.59
